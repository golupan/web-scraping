# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.flipkart.com/ajy/~cs-7d5gd723be/pr?sid=ajy&collection-tab-name=BBD+2024+Noise+Smartwatches&pageCriteria=default&param=5781&hpid=Y8tEWNmThOXtFwc8qea15Kp7_Hsxr70nj65vMAAFKlc%3D&ctx=...%3D"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

products = []

for item in soup.select(".product-grid-item"):
    name = item.select_one(".product-title").get_text(strip=True)
    price = item.select_one(".money").get_text(strip=True)
    image_url = item.select_one("img")["src"]
    link = item.select_one("a")["href"]
    
    products.append({
        "Name": name,
        "Price": price,
        "Image URL": "https:" + image_url,
        "Product Link": "https://plantify.in" + link
    })

df = pd.DataFrame(products)
df.to_csv("plantify_products.csv", index=False)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
titles = []
titles = soup.find_all("a",class_ = "wjcEIp")
for i in titles[:5]:
    print(i.get_text())
# Out:
# Noise Crew 1.38 Round Display with Bluetooth Calling, M...
# Noise Icon 2 Elite Edition 1.8'' Display with Metallic ...
# Noise Crew Go with 1.39" Display, BT Calling with Metal...
# Noise Colorfit Icon 2 1.8'' Display with Bluetooth Call...
# Noise Icon 2 Elite Edition 1.8'' Display with Metallic ...

# %%
price = []
price = soup.find_all("div",class_ = "Nx9bqj")
for j in price[:5]:
    print(j.get_text())
# Out:
# ₹1,099
# ₹1,499
# ₹1,599
# ₹999
# ₹1,499

# %%
review = []
review = soup.find_all("div",class_ = "XQDdHH")
for k in review[:5]:
    print(k.get_text())
# Out:
# 4.2
# 4.1
# 4.2
# 4.1
# 4.1

# %%
min_len = min(len(titles), len(price),len(review))

# %%
# Combine into a DataFrame
df = pd.DataFrame({
    "titles": titles[:min_len],
    "Price": price[:min_len],
    "review":review[:min_len]
})
print(df)
# Out:
#                                                titles     Price     review
# 0   [Noise Crew 1.38 Round Display with Bluetooth ...  [₹1,099]  [4.2, []]
# 1   [Noise Icon 2 Elite Edition 1.8'' Display with...  [₹1,499]  [4.1, []]
# 2   [Noise Crew Go with 1.39" Display, BT Calling ...  [₹1,599]  [4.2, []]
# 3   [Noise Colorfit Icon 2 1.8'' Display with Blue...    [₹999]  [4.1, []]
# 4   [Noise Icon 2 Elite Edition 1.8'' Display with...  [₹1,499]  [4.1, []]
# 5   [Noise Crew 1.38 Round Display with Bluetooth ...  [₹1,099]  [4.2, []]
# 6   [Noise Icon Buz 1.69" Display with Bluetooth C...  [₹1,099]  [4.1, []]
# 7   [Noise Colorfit Icon 2 1.8'' Display with Blue...    [₹999]  [4.1, []]
# 8   [Noise Crew 1.38 Round Display with Bluetooth ...  [₹1,099]  [4.2, []]
# 9   [Noise Icon Buzz 1.69" Display with Bluetooth ...  [₹1,099]  [4.1, []]
# 10  [Noise Colorfit Icon 2 1.8'' Display with Blue...    [₹999]  [4.1, []]
# ...

# %%
# Export to CSV
df.to_csv("products.csv", index=False)

# Export to JSON
df.to_json("products.json", orient="records", indent=2)

# %%
df.to_csv("watch.csv")
